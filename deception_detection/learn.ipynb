# %%
import os
import pickle

# %%
file_path = "/workspace/deception-detection/results/repe_lr__repe_honesty__plain__llama-70b-3.3__20251207_162132/detector.pt"

# %%
with open(file_path, "rb") as f:
    data = pickle.load(f)

# %%
data.keys()
# Out:
# dict_keys(['layers', 'directions', 'scaler_mean', 'scaler_scale', 'normalize', 'reg_coeff'])

# %%
data["directions"].shape
# Out:
# torch.Size([80, 8192])
